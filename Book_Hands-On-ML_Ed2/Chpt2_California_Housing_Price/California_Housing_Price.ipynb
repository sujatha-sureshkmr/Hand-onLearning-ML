# %% [markdown]
# <a href="https://colab.research.google.com/github/sujatha-sureshkmr/ReinforcementLearning/blob/master/Book_Hands-On-ML_Ed2/Chpt2_California_Housing_Price/California_Housing_Price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Here are the main steps you will go through:
#
# 1. Look at the big picture.
# 2. Get the data.
# 3. Discover and visualize the data to gain insights.
# 4. Prepare the data for Machine Learning algorithms.
# 5. Select a model and train it.
# 6. Fine-tune your model.
# 7. Present your solution.
# 8. Launch, monitor, and maintain your system.

# %% [markdown]
# **Objective:** A prediction of a district’s median housing price. The downstream system will determine whether it is worth investing in a given area or not. Getting this right is critical, as it directly affects revenue.
#
# > Supervised Learning (each instance comes with the expected output, i.e., the district’s median housing price)
#
# > Regression task : Predict a value (district pricing)
#
# > Multiple regression problem -> Multiple inputs
#
# > Univariate regression problem -> Predict single value for each district or group
#
#
#
# ![image.png](data:image/png;base64,...)
